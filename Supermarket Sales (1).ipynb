# %% [markdown]
# <p style="font-family: Arials; line-height: 2; font-size: 30px; font-weight: bold; letter-spacing: 2px; text-align: center; color:#0E0130">Supermarket Sales EDA</p>

# %% [markdown]
# ![](https://images.unsplash.com/photo-1578916171728-46686eac8d58?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxzZWFyY2h8Nnx8c3VwZXJtYXJrZXR8ZW58MHx8MHx8&auto=format&fit=crop&w=500&q=60)

# %% [markdown]
# <p style="font-family: Arials; font-size: 20px; font-style: normal; font-weight: bold; letter-spacing: 3px; color: #808080; line-height:1.0">        TABLE OF CONTENT</p>
#
# <p style="font-family: Arials; font-size: 16px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3"><a href="#part1" style="color:#808080">0 Introduction and Data Dictionary</p>
#
# <p style="font-family: Arials; font-size: 16px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3"><a href="#part2" style="color:#808080">1 IMPORTING LIBRARIES</p>
#
# <p style="font-family: Arials; font-size: 16px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3"><a href="#part3" style="color:#808080">2 DATA WRANGLING</a></p>
#
# <p style="text-indent: 1vw; font-family: Arials; font-size: 14px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3">
# <a href="#part4" style="color:#808080">2.1 Data types</a></p>
#
# <p style="text-indent: 1vw; font-family: Arials; font-size: 14px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3">
# <a href="#part5" style="color:#808080">2.2 Missing values</a></p>
#
# <p style="text-indent: 1vw; font-family: Arials; font-size: 14px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3">
# <a href="#part6" style="color:#808080">2.3 Duplicates</a></p>
#
# <p style="text-indent: 1vw; font-family: Arials; font-size: 14px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3">
# <a href="#part7" style="color:#808080">2.4 Structuring</a></p>
#
# <p style="font-family: Arials; font-size: 16px; font-style: normal;font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3"><a href="#part9" style="color:#808080">3 DATA VISUALIZATION</a></p>
#
# <p style="font-family: Arials; font-size: 16px; font-style: normal;font-weight: bold ; letter-spacing: 2px; color: #808080; line-height:1.3"><a href="#part10" style="color:#808080">4 FINAL CONCLUSIONS</a></p>
#
# <p style="text-indent: 1vw; font-family: Arials; font-size: 14px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3">
# <a href="#part11" style="color:#808080">4.1 Findings</a></p>
#
# <p style="text-indent: 1vw; font-family: Arials; font-size: 14px; font-style: normal; font-weight: bold; letter-spacing: 2px; color: #808080; line-height:1.3">
# <a href="#part12" style="color:#808080">4.2 Recommendations</a></p>

# %% [markdown]
# <p id="part1"></p>
# <p style="font-family: Arials; line-height: 2; font-size: 20px; font-weight: bold; letter-spacing: 1px; color: #0E0130">0 Introduction and Data Dictionary</p>
# <hr style="height: 0.5px; border: 0; background-color: #808080">

# %% [markdown]
# - The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data , So we aim to help sales manager to know more about prdocuts` sales and customer attributes to increase sales and make higher profit

# %% [markdown]
# |Column     | Explanation   |
# | --------- | -----------------------------------------------------------------------------------------------------------|
# |Invoice id | Computer generated sales slip invoice identification number                                                |
# |Branch     |Branch of supercenter (3 branches are available identified by A, B and C).                                      |
# |City       | Location of supercenters
# |Customer type| Type of customers, recorded by Members for customers using member card and Normal for without member card|
# |Gender |Gender type of customer
# |Product line| General item categorization groups
# |Unit price| Price of each product in $
# |Quantity| Number of products purchased by customer
# |Tax| 5% tax fee for customer buying
# |Total| Total price including tax
# |Date| Date of purchase (Record available from January 2019 to March 2019)
# |Time| Purchase time (10am to 9pm)
# |Payment| Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# |COGS| Cost of goods sold
# |Gross margin percentage| Gross margin percentage
# |Gross income| Gross income
# |Rating | Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# <p id="part2"></p>
# <p style="font-family: Arials; line-height: 2; font-size: 20px; font-weight: bold; letter-spacing: 1px; color: #0E0130">1 Importing Libraries</p>
# <hr style="height: 0.5px; border: 0; background-color: #808080">

# %%
import numpy as np # linear algebra	
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns
import waterfall_chart
# %matplotlib inline

plt.rcParams.update(
    {"font.size": 11, "figure.facecolor": "w", "axes.facecolor": "w", "axes.spines.right": False,"axes.spines.top": False, "axes.spines.bottom": False,
        "xtick.top": False,
        "xtick.bottom": False,
        "ytick.right": False,
        "ytick.left": False,
    }
)

plt.rcParams['figure.figsize'] = (12, 4)


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/laptop/Desktop/Datasets/Datasets/supermarket_sales - Sheet1.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# <p id="part3"></p>
# <p style="font-family: Arials; line-height: 2; font-size: 20px; font-weight: bold; letter-spacing: 1px; color: #0E0130">1 Data Wrangling</p>
# <hr style="height: 0.5px; border: 0; background-color: #808080">

# %%
#Taking an overall look
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Looking at nuumeric info
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# - There is no invalid data
# - Max gross is 49.65, Avg gross is 15.3 , Min gross is 0.5
# - Max Total is 1042.65 , Avg Total is 322.96 , Min Total is 10.678
# - **Math Note** :  tax/total  = gross mergin percentage / gross income thats why 5/100 = 4.761905 / 95

# %% [markdown]
# <p id="part4"></p>
#
# <p style="font-family: Arials; font-size: 18px; font-style: normal; font-weight: normal; letter-spacing: 1px; color: #0E0130; line-height:1.0">2.1 Data Types </p>

# %%
#Looking at Data types
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# - I prefer changing Time and Date columns to datatime type

# %%
#Changing Data Types to 'datatime64[ns]'
df['Time'] = pd.to_datetime(df['Time'])
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# <p id="part5"></p>
#
# <p style="font-family: Arials; font-size: 18px; font-style: normal; font-weight: normal; letter-spacing: 1px; color: #0E0130; line-height:1.0">2.2 Missing Values </p>

# %%
#Checking Null Values
for col in df.columns:
    pct_missing = df[col].isnull().mean()
    print(f'{col} - {pct_missing :.1%}')
# Out:
# Invoice ID - 0.0%
# Branch - 0.0%
# City - 0.0%
# Customer type - 0.0%
# Gender - 0.0%
# Product line - 0.0%
# Unit price - 0.0%
# Quantity - 0.0%
# Tax 5% - 0.0%
# Total - 0.0%
# Date - 0.0%
# Time - 0.0%
# Payment - 0.0%
# cogs - 0.0%
# gross margin percentage - 0.0%
# gross income - 0.0%
# Rating - 0.0%

# %% [markdown]
# - There is no Missing Values

# %% [markdown]
# <p id="part6"></p>
#
# <p style="font-family: Arials; font-size: 18px; font-style: normal; font-weight: normal; letter-spacing: 1px; color: #0E0130; line-height:1.0">2.3 Duplicates </p>

# %%
# Checking if there are duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There is NO duplicates
# - **So our data is clean 😄**

# %% [markdown]
# <p id="part7"></p>
#
# <p style="font-family: Arials; font-size: 18px; font-style: normal; font-weight: normal; letter-spacing: 1px; color: #0E0130; line-height:1.0">2.4 Structuring </p>

# %% [markdown]
# - I won`t need the Inovice ID column , So i will drop it

# %%
#Dropping Invoice ID Column
df = df.drop('Invoice ID' , axis = 1)

# %%
#Making a column for Month
df['Month'] = df['Date'].dt.month_name()

#Making a column for Month Number(it will be useful in sorting)

df['Month_Number'] = df['Date'].dt.month

# %%
#Making a Column for Hour
df['Hour'] = df['Time'].dt.hour

#Knowing more about hour column
df['Hour'].describe()
# Out:
# count    1000.000000
# mean       14.910000
# std         3.186857
# min        10.000000
# 25%        12.000000
# 50%        15.000000
# 75%        18.000000
# max        20.000000
# Name: Hour, dtype: float64

# %% [markdown]
# - So Supermrkets opens from 10 am to 8 pm

# %%
#Making Parts of day column
time = []
for i in df['Hour']:
    if i>9 and i < 13 :
        time.append('Morning')
    elif i> 12 and i < 18:
        time.append('Afternoon') 
    else:
        time.append('Evening')
df['Part_Of_The_Day'] = time

# %% [markdown]
# - Now We don`t need [Time , Hour] columns , i will drop them

# %%
# Dropping some useless Columns
df = df.drop([ 'Hour' , 'Time'] ,axis =1)

# %%
# Checking if there a changing in groos margin percentage
sns.lineplot(x ='Branch', y = 'gross margin percentage' , data = df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross margin percentage'>

# %% [markdown]
# - There is NO changing in gross margin percentage , so we can drop this column too

# %%
#Dropping gross margin percentage column
df = df.drop('gross margin percentage' , axis =1)

# %% [markdown]
# - We all know Myanmar capital Naypyidaw ,but it seems that there is an error in writing , so we will replace it

# %%
#Check Values
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
#Replacing Naypyidaw with Naypyitaw
df['City'] = df['City'].replace(['Naypyitaw'] ,  'Naypyidaw')

#Check again
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyidaw', 'Mandalay'], dtype=object)

# %%
#Checking our data 
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyidaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyidaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date      Payment    cogs  \
# ...

# %%
#Check the Dimensions
shape=df.shape
print('Number of Rows : ',shape[0])
print('Number of Columns : ',shape[1])
# Out:
# Number of Rows :  1000
# Number of Columns :  17

# %% [markdown]
#  <p style="font-family:verdana;  line-height: 1.5; font-size: 20px; font-weight: bold; letter-spacing: 1px; text-align: center; color: #0E0130">Our Data is ready to EDA and Analysis Now.</p>

# %% [markdown]
# <p id="part9"></p>
# <p style="font-family: Arials; line-height: 2; font-size: 20px; font-weight: bold; letter-spacing: 1px; color: #0E0130">3 DATA VISUALIZATION</p>
# <hr style="height: 0.5px; border: 0; background-color: #808080">

# %% [markdown]
# **Q1. Which product line has the highest average rating?**

# %%
#Groupping Product line by rating
groupped_product = df.groupby('Product line')['Rating'].mean().reset_index(drop=False)

#Rounding Rating column to 1 number
groupped_product_rating = groupped_product.round(1)

#Sorting by average rating
groupped_product_rating = groupped_product_rating.sort_values(by= 'Rating' , ascending =False)

#Chossing palette
palette = sns.color_palette('Greens_d')
palette.reverse()

#Make a horizontal bar graph for rating for each product line
ax = sns.barplot(y = 'Product line' , x = 'Rating' , data = groupped_product_rating, palette =palette)

#Showing Values
ax.bar_label(ax.containers[0])

#Setting a title
plt.title('Rating for Product Lines')
# Out:
# Text(0.5, 1.0, 'Rating for Product Lines')

# %% [markdown]
# - There is no big difference between ratings
# - Food and Beverages has the best raitng , while Home and lifestyle has the worst rating

# %% [markdown]
# **Q2. Which product line has the highest average sales?**

# %%
#Groupping Product line by rat
groupped_product_total = df.groupby('Product line')['Total'].mean().reset_index(drop=False)

#Rounding Rating column to 1 number
groupped_product_total = groupped_product_total.round(1)

#Making a scatter plot for Product lines` average sales
sns.scatterplot(x = 'Product line' , y = 'Total' , data = groupped_product_total)

#Data labels
annotations= groupped_product_total['Total']
for i, label in enumerate(annotations):
    plt.annotate(label, (groupped_product_total['Product line'][i], groupped_product_total['Total'][i]))


#Making a horizontal line for average
plt.axhline(y=np.nanmean(df.Total), color='red', linestyle='--', linewidth=3, label='Avg')
plt.legend()

#Setting a title
plt.title('Average Sales for Product Lines')
# Out:
# Text(0.5, 1.0, 'Average Sales for Product Lines')

# %% [markdown]
# - Home and lifestyle , Sports and travel have average sales more than the general average
# - Food and beverages, Health and beauty have average sales close to the general average
# - Fashion accessories and Electronic accessories have average sales less than the general average

# %% [markdown]
# **Q3 : How many quantities did we sell in the last 3 months?**

# %%
#Groupping Month by quantity
groupped_quantity = df.groupby(['Month' , 'Month_Number'])['Quantity'].sum().reset_index(drop = False)

#Sorting by Month
groupped_quantity = groupped_quantity.sort_values(by = 'Month_Number')

#Making a lineplot for Month and Quantity
sns.lineplot(x = 'Month' , y = 'Quantity' , data = groupped_quantity , marker ='o')

#Data labels
xpoints =  [0,1,2]
ypoints = groupped_quantity['Quantity']
for x, y in zip(xpoints, ypoints):
    plt.annotate(y,xy=(x, y), xytext=(-2, 6),textcoords='offset points', ha='center', va='bottom')

# %% [markdown]
# - In January , We have sold the highest quantity , then March , then February

# %% [markdown]
# **Q4 : In which month have we achieved the highest sales?**

# %%
#Groupping Month by Total(Sales)
groupped_sales =  df.groupby(['Month' , 'Month_Number'])['Total'].sum().reset_index(drop = False)

#Sorting Values by Month Number
groupped_sales = groupped_sales.sort_values(by = 'Month_Number')

#Rounding Sales to 1 number
groupped_sales = groupped_sales.round(1)

#Plotting Waterfall Chart
waterfall_chart.plot(groupped_sales['Month'],groupped_sales['Total'], formatting='{:,.3f}')

#Make a title
plt.title('Total Sales Per Month')
# Out:
# Text(0.5, 1.0, 'Total Sales Per Month')

# %% [markdown]
# - We have made 322k dollars sales in last 3 months .
# - The highest sales were in January with 116k $

# %% [markdown]
# **Q5 : What is the distribution of customer type ?**

# %%
# Out:
# Text(0.5, 1.0, 'Distribution of customer type count')

# %% [markdown]
# - The counts of Members is alomst equal to the number of normal Customers

# %%
#Reset plots settings
plt.style.use('default')
plt.rcParams.update(
    {"font.size": 11, "figure.facecolor": "w", "axes.facecolor": "w", "axes.spines.right": False,"axes.spines.top": False, "axes.spines.bottom": False,
        "xtick.top": False,
        "xtick.bottom": False,
        "ytick.right": False,
        "ytick.left": False,
    }
)
plt.rcParams['figure.figsize'] = (12, 4)

# %% [markdown]
# **Q6 : Which part of the day has the highest gross income average ?**

# %%
#Groupping Part of the day by gross income
groupped_day = df.groupby('Part_Of_The_Day')['gross income'].mean().reset_index(drop =False)

#Making a line plot
sns.lineplot(x = 'Part_Of_The_Day' , y ='gross income' ,  data = groupped_day,marker ='o')

#Rounding gross income to 1 decimal number
groupped_day = groupped_day.round(1)

#Showing data labels
xpoints =  [0,1,2]
ypoints = groupped_day['gross income']
for x, y in zip(xpoints, ypoints):
    plt.annotate(y,xy=(x, y), xytext=(-2, 6),textcoords='offset points', ha='center', va='bottom')
    
#Setting title
plt.title('Average Gross income during the day')
# Out:
# Text(0.5, 1.0, 'Average Gross income during the day')

# %% [markdown]
#  - The best average gross income is in afternoon ,then evening and Morning

# %% [markdown]
# **Q7 : Which City has the highest gross income average ?**

# %%
#Groupping city by gross income
groupped_city= df.groupby('City')['gross income'].mean().reset_index(drop =False)

#Making a line plot
sns.lineplot(x = 'City' , y ='gross income' ,  data = groupped_city,marker ='o')

#Round gross income to 1 decimal number
groupped_city = groupped_city.round(1)

#Showing data labels
xpoints =  [0,1,2]
ypoints = groupped_city['gross income']
for x, y in zip(xpoints, ypoints):
    plt.annotate(y,xy=(x, y), xytext=(-2, 6),textcoords='offset points', ha='center', va='bottom')

# %% [markdown]
# - The average gross income increases in Naypyidaw city
# - Yangon city has the lowest gross income average

# %% [markdown]
# **Q8 : Which part of the day has the highest gross income average city-wise?**

# %%
#Groupping City , Part of the day by gross income
groupped_city_day = df.groupby(['City' , 'Part_Of_The_Day'])['gross income'].mean().reset_index(drop =False)
#Making a line plot
sns.lineplot(x = 'Part_Of_The_Day' , y ='gross income' , hue = 'City' , data = groupped_city_day,marker ='o')

#Setting title
plt.title('Average Gross income during the day in each city')
# Out:
# Text(0.5, 1.0, 'Average Gross income during the day in each city')

# %% [markdown]
# - The highest gross income average is in Naypyidaw city in the afternoon
# - The lowest gross income average is in Yangon city in the evening
# - Our customers in Yangon city prefer purchase in the Afternoon
# - Our customers in Mandalay city prefer purchase in the Morning
# - Our customers in Naypyidaw city prefer purchase in the evening

# %% [markdown]
# **Q9 :What is the distribution of Payment ?**

# %%
#Setting the figure and the axis to make multpie charts 
fig, axis = plt.subplots(nrows = 1 , ncols = 2)
fig.set_figwidth(10)
fig.set_figheight(12)


#Making a donut chart for payment type
plt.style.use('classic')
plt.style.use('Solarize_Light2')
df.groupby('Payment').count()['cogs'].plot(kind='pie', autopct= '%.2f', figsize=(10,7),subplots=True, wedgeprops=dict(width=0.20), ax =axis[0])
axis[0].set_title('Distribution of Payment ')

#Making a donut chart for Gender
plt.style.use('classic')
plt.style.use('Solarize_Light2')
df.groupby('Gender').count()['cogs'].plot(kind='pie', autopct= '%.2f', figsize=(10,7),subplots=True, wedgeprops=dict(width=0.20), ax =axis[1])
axis[1].set_title('Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %% [markdown]
# - Male and Female Customers have an equal distribution
# - Ewallet and Cash the most common payment ways, while Credit Card are less common

# %%
#Reset plots settings again
plt.style.use('default')
plt.rcParams.update(
    {"font.size": 11, "figure.facecolor": "w", "axes.facecolor": "w", "axes.spines.right": False,"axes.spines.top": False, "axes.spines.bottom": False,
        "xtick.top": False,
        "xtick.bottom": False,
        "ytick.right": False,
        "ytick.left": False,
    }
)
plt.rcParams['figure.figsize'] = (12, 4)

# %% [markdown]
# **Q10 : What is the most common payment way per Gender?**

# %%
#Making a multipie bar chart
ad = sns.countplot(x = 'Gender' , hue= 'Payment' , data =df , palette = 'Accent_r')

#Setting legends
plt.legend(bbox_to_anchor=(0.5, 1.02),loc="upper right",borderaxespad=0,frameon=False,ncol=3,  prop = {'size' : 9})


#Data labels
ad.bar_label(ad.containers[0])
ad.bar_label(ad.containers[1])
ad.bar_label(ad.containers[2])


#Set title
plt.title('Distribution of Payment per Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Payment per Gender')

# %% [markdown]
# - From the last bar chart , We can see that Males often pay with E wallet
# - Women prefer pay with Cash

# %% [markdown]
# **Q11 : What is the most common Product lines per Customer Type?**

# %%
plt.figure(figsize = (12,4))
#Making a multipie bar chart
ag = sns.countplot(x = 'Product line' , hue= 'Customer type' , data =df , palette = 'coolwarm')

#Setting legends settings
plt.legend(loc="upper left" , prop = {'size' : 6})

#Data labels
ag.bar_label(ag.containers[0])
ag.bar_label(ag.containers[1])

#Set title
plt.xticks(rotation = 45)
plt.title('Distribution of Payment per Customer type')
# Out:
# Text(0.5, 1.0, 'Distribution of Payment per Customer type')

# %% [markdown]
# - Member Customers prefer buy Food and beverages , Sports and Travel
# - Normal (non-member) Customers prefer buy electronic and fashion accessories

# %% [markdown]
# **Q12 : What are the intersts of each Gender ?**

# %%
cross_tab = pd.crosstab(index = df['Gender'] , columns = df['Product line'] )
cross_tab_prop = pd.crosstab(index = df['Gender'] , columns = df['Product line' ] , normalize="index" )

# %%
cross_tab_prop.plot(kind='barh', 
                        stacked=True, 
                        colormap='coolwarm')

plt.legend(bbox_to_anchor=(0.5, 1.02),loc="lower center",borderaxespad=0,frameon=False,ncol=3)
plt.ylabel("Release Year")
plt.xlabel("Proportion")


for n, x in enumerate([*cross_tab.index.values]):
    for (proportion, count, y_loc) in zip(cross_tab_prop.loc[x],
                                          cross_tab.loc[x],
                                          cross_tab_prop.loc[x].cumsum()):
                
        plt.text(x=(y_loc - proportion) + (proportion / 2)-0.05,
                 y=n - 0.12,
                 s=f'{count}\n({np.round(proportion * 100, 1)}%)', 
                 color="black",
                 fontsize=10,
                 fontweight="bold")

plt.show()

# %% [markdown]
# - From the last stacked bar chart , we can see that Females are interested in Fashion accessories , they aren`t interested in Health and Beauty Products
# - Males are interested in all categories , but they are interested in Health and Beauty the most

# %% [markdown]
# **Q13 : What are the Product lines sales Gender-wise?**

# %%
cross_tab1 = pd.crosstab(index = df['Product line'] , columns = df['Gender'] )
cross_tab_prop1 = pd.crosstab(index = df['Product line'] , columns = df['Gender' ] , normalize="index" )

# %%
cross_tab_prop1.plot(kind='barh', 
                        stacked=True, 
                        colormap='coolwarm')

plt.legend(bbox_to_anchor=(0.5, 1.02),loc="lower center",borderaxespad=0,frameon=False,ncol=3)
plt.ylabel("Release Year")
plt.xlabel("Proportion")


for n, x in enumerate([*cross_tab1.index.values]):
    for (proportion, count, y_loc) in zip(cross_tab_prop1.loc[x],
                                          cross_tab1.loc[x],
                                          cross_tab_prop1.loc[x].cumsum()):
                
        plt.text(x=(y_loc - proportion) + (proportion / 2)-0.05,
                 y=n - 0.12,
                 s=f'{count}({np.round(proportion * 100, 1)}%)', 
                 color="black",
                 fontsize=10,
                 fontweight="bold")

plt.show()

# %% [markdown]
# - Males purchase Health and Beauty Products more than Females
# - Females purchase Sports and Travel , Fashion accessories Products more than Males
# - Males purchase almost Home and lifestyle , Food and beverages products as much as Females

# %% [markdown]
# **Q14 : Which Gender has had the highest total sales ?**

# %%
#Groupping Gender by Total sales
groupped_gender = df.groupby('Gender')['Total'].sum().reset_index()

#Make a barplot for sales
gender = sns.barplot(x ='Gender' , y = 'Total' , data =groupped_gender , palette = 'rocket_r' )

#Data labels
gender.bar_label(gender.containers[0])

#Set title
plt.title('Total Sales Per Gender')
# Out:
# Text(0.5, 1.0, 'Total Sales Per Gender')

# %% [markdown]
# - Female paid more than men in last three months

# %% [markdown]
# **Q15 : Which Gender has had the highest total sales City-wise?**

# %%
#Groupping Gender ,City by Total sales
groupped_gender_city = df.groupby(['Gender' , 'City'])['Total'].sum().reset_index()

#Make a barplot for sales
gender_city = sns.barplot(x ='City' , y = 'Total' , hue = 'Gender',data =groupped_gender_city , palette = 'rocket_r' )

#Data labels
gender_city.bar_label(gender_city.containers[0])
gender_city.bar_label(gender_city.containers[1])

#Set legends
plt.legend(bbox_to_anchor=(0.5, 1.02),loc="upper left",borderaxespad=0,frameon=False,ncol=3,  prop = {'size' : 9})

#Set title
plt.title('Total Sales Per Gender and City')
# Out:
# Text(0.5, 1.0, 'Total Sales Per Gender and City')

# %% [markdown]
# - Females paid more than Males in Naypyidaw city
# - Females total purchases is close to Males total purchases in the other two cities

# %% [markdown]
# **Q16 : Which Prodcut line has had the highest average sales City-wise?**

# %%
#Groupping Product line , city by sales
groupped_product_city =  df.groupby(['City' , 'Product line'])['Total'].sum().reset_index()

#Making a bar plot 
ap =sns.barplot(x =  'Product line', y = 'Total' , hue = 'City' ,data = groupped_product_city , palette =  'crest')

#Rotate x labels
plt.xticks(rotation = 45)

#Data labels
ap.bar_label(ap.containers[0] , fontsize= 9)
ap.bar_label(ap.containers[1] , fontsize = 9)
ap.bar_label(ap.containers[2] , fontsize = 9)

#Set legends
plt.legend(loc= 'upper left' , prop ={'size' : 7})

#Set title
plt.title('Total Sales Per Product lines and City')
# Out:
# Text(0.5, 1.0, 'Total Sales Per Product lines and City')

# %% [markdown]
# - In city Yangon, customers spend on Health and Beauty the least and Home and Lifestyle the most.
# - In city Mandalay, customers spend on Food and Beverages the least and Sports and travel the most.
# - In city Naypyidaw, customers spend on Home and lifestyle the least and Food and Beverages the most

# %% [markdown]
# **Q17 : Which branch has had the highest average sales?**

# %%
#Groupping branch by average sales
groupped_branch = df.groupby('Branch')['Total'].mean().reset_index()

#Making a bar plot 
branch = sns.barplot(x = 'Branch' , y = 'Total' , data = groupped_branch , palette = 'coolwarm')

#Data labels
branch.bar_label(branch.containers[0])


#Set title
plt.title('Average Sales Per Branch')
# Out:
# Text(0.5, 1.0, 'Average Sales Per Branch')

# %% [markdown]
# - Branch C has the highest average sales

# %% [markdown]
# <p id="part10"></p>
# <p style="font-family: Arials; line-height: 2; font-size: 20px; font-weight: bold; letter-spacing: 1px; color: #0E0130">4 FINAL CONCLUSTIONS</p>
# <hr style="height: 0.5px; border: 0; background-color: #808080">

# %% [markdown]
# <p id="part11"></p>
#
# <p style="font-family: Arials; font-size: 18px; font-style: normal; font-weight: normal; letter-spacing: 1px; color: #0E0130; line-height:1.0">4.1 Findings </p>

# %% [markdown]
# - Food and Beverages has the best raitng , while Home and lifestyle has the worst rating
# - Home and lifestyle , Sports and travel have average sales more than the general average
# - Food and beverages, Health and beauty have average sales close to the general average
# - Fashion accessories and Electronic accessories have average sales less than the general average
# - In January , We have sold the highest quantity , then March , then February
# - We have made 322k dollars sales in last 3 months .
# - The highest sales were in January with 116k $
# - The counts of Members is alomst equal to the number of normal (non-member) Customers
# - The best average gross income is in afternoon ,then evening and Morning
# - The average gross income increases in Naypyidaw city
# - Yangon city has the lowest gross income average
# - The highest gross income average is in Naypyidaw city in the afternoon
# - The lowest gross income average is in Yangon city in the evening
# - Our customers in Yangon city prefer purchase in the Afternoon
# - Our customers in Mandalay city prefer purchase in the Morning
# - Our customers in Naypyidaw city prefer purchase in the evening
# - Male and Female Customers have an equal distribution
# - Ewallet and Cash the most common payment ways, while Credit Card are less common
# - Males often pay with Ewallet
# - Women prefer pay with Cash
# - Member Customers prefer buy Food and beverages , Sports and Travel
# - Normal (non-member) Customers prefer buy electronic and fashion accessories
# - Females are interested in Fashion accessories , they aren`t interested in Health and Beauty Products
# - Males are interested in all categories , but they are interested in Health and Beauty the most
# - Males purchase Health and Beauty Products more than Females
# - Females purchase Sports and Travel , Fashion accessories Products more than Males
# - Males purchase almost Home and lifestyle , Food and beverages products as much as Females
# - Female paid more than men in last three months
# - Females paid more than Males in Naypyidaw city
# - Females total purchases is close to Males total purchases in the other two cities(Mandalay , Yangon)
# - In city Yangon, customers spend on Health and Beauty the least and Home and Lifestyle the most.
# - In city Mandalay, customers spend on Food and Beverages the least and Sports and travel the most.
# - In city Naypyidaw, customers spend on Home and lifestyle the least and Food and Beverages the most
# - Branch C has the highest average sales

# %% [markdown]
# <p id="part12"></p>
#
# <p style="font-family: Arials; font-size: 18px; font-style: normal; font-weight: normal; letter-spacing: 1px; color: #0E0130; line-height:1.0">4.2 Recommendations </p>

# %% [markdown]
# - You should improve Home and lifestyle products quality
# - You should pay more attention for electronic and fashion accessorie by Make discounts and Advs and convert non-member customers to members because the are interested in these products
# - As we see the number of members is alomst equal to the number of normal (non-member) Customers , So the benefits of using member cards should be conveyed to the normal customers which will convert them to a member which means more sales and customer loyalty
# - You should pay more attention to Males by give them promo codes when they buy with their favorite payment way(ewallet) and make discounts on Health and beauty products
# - Make some dicounts in the morning to attract more customers
# - If you decided to open new branches , You should open them in Naypyidaw city
# - For Females , you should run more ad campaigns where they should tell the importance of overall health
# - Learn from your actions in January when you gained the much

# %% [markdown]
#  <p style="font-family: verdana; line-height: 1.5; font-size: 16px; font-weight: bold; letter-spacing: 1px; text-align: center; color: #0E0130">If you liked this notebook, please put your votes and leave some of your recommendations.</p>
